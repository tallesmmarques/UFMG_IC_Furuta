# %%
import serial
from scipy.optimize import curve_fit
from scipy.signal import lsim, TransferFunction
import matplotlib.pyplot as plt
import time
import numpy as np
import json
import pandas as pd

# %%
port = 'COM4'
mult = 1000

V_max = 9 # Volts

def get_serial_data(f0, f1, chirp_pwm):
    data_names = []
    data_recv = {}
    with serial.Serial(port, 115200, timeout=3) as ser:
        params = f"{f0},{f1},{chirp_pwm}\n"
        print("Sending: ", params)
        time.sleep(5)
        ser.write(params.encode())
        time.sleep(0.1)
        
        print("Reading", end='')
        read_first_data = False
        count = 0

        ser.flush()        
        while True:
            data = ser.readline().decode('utf-8').strip()
            if data:
                split_data = data.split(';')
                if not read_first_data:
                    data_names = split_data
                    for i in range(len(data_names)):
                        data_recv[data_names[i]] = []
                    read_first_data = True
                    continue
                numbers = [float(num) for num in split_data]
                for i in range(len(data_names)):
                    data_recv[data_names[i]].append(numbers[i]/mult)
                
                if count % 100 == 0:
                    print('.', end='')
                count += 1
            else:
                if read_first_data:
                    break
        print()
    return data_names, data_recv

def simulate_first_order_system(time, K, tau, V):
    num = [K]
    den = [tau, 1]

    system = TransferFunction(num, den)
    _, y_out, _ = lsim(system, U=V, T=time)

    return y_out

# %% [markdown]
# # Experiment 1

# %% [markdown]
# Captura de dados, execute apenas se necessário, caso contrário siga para a próxima celula!

# %%
ret = get_serial_data(0.075, 5, 1)

data_names = ret[0]
data = ret[1]
print(data_names)

with open("exp_1.json", "w") as file:
    json.dump(data, file, indent=4)
# Out:
# Sending:  0.075,5,1
#
# Reading........................................................................................................................
# ['t', 'u', 'theta_1']

# %%
with open("exp_1.json", "r") as file:
    data = json.load(file)

data["omega_1"] = np.gradient(data["theta_1"])/np.gradient(data["t"])
data["V"] = np.array(data["u"]) * V_max

plt.plot(data["t"], data["V"], label="V")
plt.plot(data["t"], data["omega_1"], label="omega_1")
plt.legend()
plt.show()

# %%
t = data["t"]
V = data["V"]
omega_1 = data["omega_1"]

ts = np.mean(np.gradient(t))
print("ts: ", ts)

t_ts = np.linspace(0, (len(t) - 1)*ts, len(t))

params, covariance = curve_fit(lambda time, K, tau: simulate_first_order_system(time, K, tau, V), t_ts, omega_1, p0=[1,1])

K1_est, tau1_est = params

print(f"K: {K1_est}, tau: {tau1_est}")

plt.plot(t, omega_1, label="real")
plt.plot(t_ts, simulate_first_order_system(t_ts, K1_est, tau1_est, V), ":", label="model")
plt.legend()
plt.show()
# Out:
# ts:  0.020012605052526267
# K: 1.7910746094545997, tau: 0.3768099770604963

# %%
K1_est_new = K1_est * 0.95 # correção manual 
tau1_est_new = tau1_est * 1

plt.plot(t, omega_1, label="real")
plt.plot(t_ts, simulate_first_order_system(t_ts, K1_est_new, tau1_est_new, V), ":", label="model")
plt.legend()
plt.show()

# %% [markdown]
# # Experiment 2

# %% [markdown]
# Captura de dados, execute apenas se necessário, caso contrário siga para a próxima celula!

# %%
ret = get_serial_data(0.075, 5, 1)

data_names = ret[0]
data = ret[1]
print(data_names)

with open("exp_2.json", "w") as file:
    json.dump(data, file, indent=4)
# Out:
# Sending:  0.075,5,1
#
# Reading........................................................................................................................
# ['t', 'u', 'theta_1']

# %%
with open("exp_2.json", "r") as file:
    data = json.load(file)

data["omega_1"] = np.gradient(data["theta_1"])/np.gradient(data["t"])
data["V"] = np.array(data["u"]) * V_max

plt.plot(data["t"], data["V"], label="V")
plt.plot(data["t"], data["omega_1"], label="omega_1")
plt.legend()
plt.show()

# %%
t = data["t"]
V = data["V"]
omega_1 = data["omega_1"]

ts = np.mean(np.gradient(t))
print("ts: ", ts)

t_ts = np.linspace(0, (len(t) - 1)*ts, len(t))

params, covariance = curve_fit(lambda time, K, tau: simulate_first_order_system(time, K, tau, V), t_ts, omega_1, p0=[1,1])

K2_est, tau2_est = params

print(f"K: {K2_est}, tau: {tau2_est}")

plt.plot(t, omega_1, label="real")
plt.plot(t_ts, simulate_first_order_system(t_ts, K2_est, tau2_est, V), ":", label="model")
plt.legend()
plt.show()
# Out:
# ts:  0.02001266049691512
# K: 1.7752367015272659, tau: 0.3663013724294518

# %%
K2_est_new = K2_est * 0.95 # correção manual 
tau2_est_new = tau2_est * 1

plt.plot(t, omega_1, label="real")
plt.plot(t_ts, simulate_first_order_system(t_ts, K2_est_new, tau2_est_new, V), ":", label="model")
plt.legend()
plt.show()

# %%
print(K1_est_new, K2_est_new)
# Out:
# 1.7015208789818697 1.6864748664509024

# %%
print(tau1_est_new/tau2_est_new)
# Out:
# 1.028688411843361

# %%
print(K1_est_new/K2_est_new)
# Out:
# 1.0089215753108913

# %%
with open("exp_1.json", "r") as file:
    data1 = json.load(file)
data1["omega_1"] = np.gradient(data1["theta_1"])/np.gradient(data1["t"])

with open("exp_2.json", "r") as file:
    data2 = json.load(file)
data2["omega_1"] = np.gradient(data2["theta_1"])/np.gradient(data2["t"])

plt.plot(data1["t"], data1["omega_1"], label="exp 1")
plt.plot(data2["t"], data2["omega_1"], label="exp 2")
plt.legend()
plt.xlim([0, data1["t"][-1]])
plt.show()

# %%
pd.read_json("exp_1.json").to_csv("exp_1.csv", index=False)
pd.read_json("exp_2.json").to_csv("exp_2.csv", index=False)
